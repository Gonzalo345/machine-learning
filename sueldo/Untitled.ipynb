# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
a = 1

# %%
a
# Out:
# 1

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
a = [1 , 3, 5, np.nan, 6, 8]

# %%
a
# Out:
# [1, 3, 5, nan, 6, 8]

# %%
a[1]
# Out:
# 3

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s[1]
# Out:
# 3.0

# %%
s[4]
# Out:
# 6.0

# %%
dates = pd.date_range("20240101", periods=13, freq='MS')

# %%
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01',
#                '2025-01-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
df = pd.DataFrame(np.random.randn(13, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01 -0.091640 -0.036248 -0.916380  0.836476
# 2024-02-01 -0.742759 -1.686248  2.483467  0.257170
# 2024-03-01 -0.227803 -1.051896  1.123286  1.413577
# 2024-04-01 -1.171533 -0.571429  0.999836 -1.359236
# 2024-05-01  0.197574  0.430699  0.797657  1.097079
# 2024-06-01 -0.043123 -0.783909  3.057125  1.161991
# 2024-07-01 -1.035505 -1.880739  1.483062  1.411775
# 2024-08-01 -1.712165 -0.688588 -1.279356 -1.448492
# 2024-09-01  0.481259  2.198110  0.111619 -0.602584
# 2024-10-01 -1.083993  0.307127  1.714376  1.246881
# 2024-11-01 -0.369580  0.299051 -0.784541  1.879557
# 2024-12-01 -0.091405 -1.233814 -0.013287  0.224030
# 2025-01-01 -0.485609 -1.315968 -1.492229 -1.007635

# %%
np.random.randn(13, 1)
# Out:
# array([[ 0.94749883],
#        [-1.05747058],
#        [ 0.66178484],
#        [ 0.65552405],
#        [ 0.73073037],
#        [ 0.19333447],
#        [-0.98917691],
#        [-1.27199657],
#        [ 0.30549114],
#        [ 0.59290314],
#        [-0.98492858],
#        [ 1.02286796],
#        [ 0.15972004]])

# %%
np.array([3] * 4, dtype="int32")
# Out:
# array([3, 3, 3, 3], dtype=int32)

# %%
pd.Series(1, index=list(range(4)), dtype="float32")
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float32

# %%
np.array([[1,2,3],[1,3,4]]*2)
# Out:
# array([[1, 2, 3],
#        [1, 3, 4],
#        [1, 2, 3],
#        [1, 3, 4]])

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2024-01-01  0.836476 -0.916380 -0.036248 -0.091640
# 2024-02-01  0.257170  2.483467 -1.686248 -0.742759
# 2024-03-01  1.413577  1.123286 -1.051896 -0.227803
# 2024-04-01 -1.359236  0.999836 -0.571429 -1.171533
# 2024-05-01  1.097079  0.797657  0.430699  0.197574
# 2024-06-01  1.161991  3.057125 -0.783909 -0.043123
# 2024-07-01  1.411775  1.483062 -1.880739 -1.035505
# 2024-08-01 -1.448492 -1.279356 -0.688588 -1.712165
# 2024-09-01 -0.602584  0.111619  2.198110  0.481259
# 2024-10-01  1.246881  1.714376  0.307127 -1.083993
# 2024-11-01  1.879557 -0.784541  0.299051 -0.369580
# 2024-12-01  0.224030 -0.013287 -1.233814 -0.091405
# 2025-01-01 -1.007635 -1.492229 -1.315968 -0.485609

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01 -0.091640 -0.036248 -0.916380  0.836476
# 2024-02-01 -0.742759 -1.686248  2.483467  0.257170
# 2024-03-01 -0.227803 -1.051896  1.123286  1.413577
# 2024-04-01 -1.171533 -0.571429  0.999836 -1.359236
# 2024-05-01  0.197574  0.430699  0.797657  1.097079
# 2024-06-01 -0.043123 -0.783909  3.057125  1.161991
# 2024-07-01 -1.035505 -1.880739  1.483062  1.411775
# 2024-08-01 -1.712165 -0.688588 -1.279356 -1.448492
# 2024-09-01  0.481259  2.198110  0.111619 -0.602584
# 2024-10-01 -1.083993  0.307127  1.714376  1.246881
# 2024-11-01 -0.369580  0.299051 -0.784541  1.879557
# 2024-12-01 -0.091405 -1.233814 -0.013287  0.224030
# 2025-01-01 -0.485609 -1.315968 -1.492229 -1.007635

# %%
dfc[20240401,dates[5],["A.lo","B"]]
# Out:
#                    A         C
# 2024-03-01 -0.227803  1.123286
# 2024-04-01 -1.171533  0.999836
# 2024-06-01 -0.043123  3.057125

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three", "asdf", "asdfa", "asdfa", "sdf", "asdf","asdfas", "asdfa"]

# %%
df[(df["B"] < 0) & (df["B"] > -1)]
# Out:
#                    A         B         C         D
# 2024-01-01 -0.091640 -0.036248 -0.916380  0.836476
# 2024-04-01 -1.171533 -0.571429  0.999836 -1.359236
# 2024-06-01 -0.043123 -0.783909  3.057125  1.161991
# 2024-08-01 -1.712165 -0.688588 -1.279356 -1.448492

# %%
df
# Out:
#                    A         B         C         D
# 2024-01-01 -0.091640 -0.036248 -0.916380  0.836476
# 2024-02-01 -0.742759 -1.686248  2.483467  0.257170
# 2024-03-01 -0.227803 -1.051896  1.123286  1.413577
# 2024-04-01 -1.171533 -0.571429  0.999836 -1.359236
# 2024-05-01  0.197574  0.430699  0.797657  1.097079
# 2024-06-01 -0.043123 -0.783909  3.057125  1.161991
# 2024-07-01 -1.035505 -1.880739  1.483062  1.411775
# 2024-08-01 -1.712165 -0.688588 -1.279356 -1.448492
# 2024-09-01  0.481259  2.198110  0.111619 -0.602584
# 2024-10-01 -1.083993  0.307127  1.714376  1.246881
# 2024-11-01 -0.369580  0.299051 -0.784541  1.879557
# 2024-12-01 -0.091405 -1.233814 -0.013287  0.224030
# 2025-01-01 -0.485609 -1.315968 -1.492229 -1.007635

# %%
df = pd.read_csv('datos.csv')

# %%
df
# Out:
#           Fecha   Compra    Venta     Fecha.1  Sueldo
# 0    02/09/2024  1275,00  1305,00  31/08/2021  96000.0
# 1    30/08/2024  1275,00  1305,00  29/09/2021  96000.0
# 2    29/08/2024  1285,00  1315,00  29/10/2021  96000.0
# 3    28/08/2024  1305,00  1335,00  30/11/2021  96000.0
# 4    27/08/2024  1310,00  1340,00  30/12/2021  96000.0
# ..          ...      ...      ...         ...      ...
# 916  07/07/2021   167,00   172,00         NaN      NaN
# 917  06/07/2021   166,00   171,00         NaN      NaN
# 918  05/07/2021   166,00   171,00         NaN      NaN
# 919  02/07/2021   165,00   170,00         NaN      NaN
# 920  01/07/2021   164,00   169,00         NaN      NaN
#
# [921 rows x 5 columns]

# %%
dolar=df.iloc[:,0:3]

# %%
dolar
# Out:
#           Fecha   Compra    Venta
# 0    02/09/2024  1275,00  1305,00
# 1    30/08/2024  1275,00  1305,00
# 2    29/08/2024  1285,00  1315,00
# 3    28/08/2024  1305,00  1335,00
# 4    27/08/2024  1310,00  1340,00
# ..          ...      ...      ...
# 916  07/07/2021   167,00   172,00
# 917  06/07/2021   166,00   171,00
# 918  05/07/2021   166,00   171,00
# 919  02/07/2021   165,00   170,00
# 920  01/07/2021   164,00   169,00
#
# [921 rows x 3 columns]

# %%
dolar=dolar.set_index('Fecha')

# %%
dolar
# Out:
#              Compra    Venta
# Fecha
# 02/09/2024  1275,00  1305,00
# 30/08/2024  1275,00  1305,00
# 29/08/2024  1285,00  1315,00
# 28/08/2024  1305,00  1335,00
# 27/08/2024  1310,00  1340,00
# ...             ...      ...
# 07/07/2021   167,00   172,00
# 06/07/2021   166,00   171,00
# 05/07/2021   166,00   171,00
# 02/07/2021   165,00   170,00
# 01/07/2021   164,00   169,00
#
# [921 rows x 2 columns]

# %%
dolar.index = pd.to_datetime(dolar.index, dayfirst=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[921], line 1
# ----> 1 dolar.index = pd.to_datetime(dolar.index, dayfirst=False)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1076, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1074         result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#    1075     else:
# -> 1076         result = convert_listlike(arg, format, name=arg.name)
#    1077 elif is_list_like(arg):
#    1078     try:
#    1079         # error: Argument 1 to "_maybe_cache" has incompatible type
#    1080         # "Union[float, str, datetime, List[Any], Tuple[Any, ...], ExtensionArray,
#    1081         # ndarray[Any, Any], Series]"; expected "Union[List[Any], Tuple[Any, ...],
# ...

# %%
dolar
# Out:
#              Compra    Venta
# Fecha
# 02/09/2024  1275,00  1305,00
# 30/08/2024  1275,00  1305,00
# 29/08/2024  1285,00  1315,00
# 28/08/2024  1305,00  1335,00
# 27/08/2024  1310,00  1340,00
# ...             ...      ...
# 07/07/2021   167,00   172,00
# 06/07/2021   166,00   171,00
# 05/07/2021   166,00   171,00
# 02/07/2021   165,00   170,00
# 01/07/2021   164,00   169,00
#
# [921 rows x 2 columns]

# %%
dolar.index.to_period('M')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[925], line 1
# ----> 1 dolar.index.to_period('M')
#
# AttributeError: 'Index' object has no attribute 'to_period'

# %%
dolar.groupby(level=0).nth(0, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[927], line 1
# ----> 1 dolar.groupby(level=0).nth(0, axis=1)
#
# TypeError: GroupByNthSelector.__call__() got an unexpected keyword argument 'axis'

# %%
a.nth()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 a.nth()
#
# TypeError: GroupByNthSelector.__call__() missing 1 required positional argument: 'n'

# %%
print(a.sum<)

# %%
speeds.groupby("class")

# %%
speeds
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
grouped=speeds.groupby("class")

# %%
print(grouped.groups)
# Out:
# {'bird': ['falcon', 'parrot'], 'mammal': ['lion', 'monkey', 'leopard']}

# %%
grouped = speeds.groupby(["class", "order"])

# %%
grouped.groups
# Out:
# {('bird', 'Falconiformes'): ['falcon'], ('bird', 'Psittaciformes'): ['parrot'], ('mammal', 'Carnivora'): ['lion', 'leopard'], ('mammal', 'Primates'): ['monkey']}

# %%
print dolar.groups
# Out:
#   Cell In[80], line 1
#     print dolar.groups
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
dolar.groups
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_59528/979249369.py in ?()
# ----> 1 dolar.groups
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'groups'

# %%
primer_dia_mes = dolar.groupby(dolar.index.to_period('M')).nth(30)

# %%
dolar2 = dolar.sort_index(axis=0, ascending=True)

# %%
dolar2
# Out:
#              Compra    Venta
# Fecha
# 2021-07-01   164,00   169,00
# 2021-07-02   165,00   170,00
# 2021-07-05   166,00   171,00
# 2021-07-06   166,00   171,00
# 2021-07-07   167,00   172,00
# ...             ...      ...
# 2024-08-27  1310,00  1340,00
# 2024-08-28  1305,00  1335,00
# 2024-08-29  1285,00  1315,00
# 2024-08-30  1275,00  1305,00
# 2024-09-02  1275,00  1305,00
#
# [921 rows x 2 columns]

# %%
primer_dia=dolar2.groupby(dolar2.index.to_period('M')).nth(0)

# %%
df=primer_dia.copy()

# %%
df['Compra'] = df['Compra'].str.replace(',', '.').astype(float)
df['Venta'] = df['Venta'].str.replace(',', '.').astype(float)

# %%
df['Compra'] = df['Compra'].astype(float)

# %%
df['Venta'] = df['Venta'].astype(float)

# %%
df
# Out:
#             Compra   Venta
# Fecha
# 2021-07-01   164.0   169.0
# 2021-08-02   175.5   180.5
# 2021-09-01   175.5   180.5
# 2021-10-01   182.0   186.0
# 2021-11-01   192.5   196.5
# 2021-12-01   196.5   200.5
# 2022-01-03   202.0   206.0
# 2022-02-01   210.0   214.0
# 2022-03-02   202.0   206.0
# 2022-04-01   196.0   200.0
# 2022-05-02   197.0   201.0
# 2022-06-01   202.0   206.0
# 2022-07-01   235.0   239.0
# 2022-08-01   272.0   282.0
# 2022-09-01   280.0   285.0
# 2022-10-03   280.0   284.0
# 2022-11-01   286.0   290.0
# 2022-12-01   309.0   313.0
# 2023-01-02   342.0   346.0
# 2023-02-01   377.0   381.0
# 2023-03-01   371.0   375.0
# 2023-04-03   391.0   395.0
# 2023-05-02   464.0   469.0
# 2023-06-01   485.0   490.0
# 2023-07-03   490.0   495.0
# 2023-08-01   555.0   560.0
# 2023-09-01   725.0   735.0
# 2023-10-02   790.0   800.0
# 2023-11-01   865.0   915.0
# 2023-12-01   905.0   955.0
# 2024-01-02   955.0  1005.0
# 2024-02-01  1165.0  1195.0
# 2024-03-01  1010.0  1040.0
# ...

# %%
df_promedio=(df["Compra"]+df["Venta"])/2

# %%
df_promedio
# Out:
# Fecha
# 2021-07-01     166.5
# 2021-08-02     178.0
# 2021-09-01     178.0
# 2021-10-01     184.0
# 2021-11-01     194.5
# 2021-12-01     198.5
# 2022-01-03     204.0
# 2022-02-01     212.0
# 2022-03-02     204.0
# 2022-04-01     198.0
# 2022-05-02     199.0
# 2022-06-01     204.0
# 2022-07-01     237.0
# 2022-08-01     277.0
# 2022-09-01     282.5
# 2022-10-03     282.0
# 2022-11-01     288.0
# 2022-12-01     311.0
# 2023-01-02     344.0
# 2023-02-01     379.0
# 2023-03-01     373.0
# 2023-04-03     393.0
# 2023-05-02     466.5
# 2023-06-01     487.5
# 2023-07-03     492.5
# 2023-08-01     557.5
# 2023-09-01     730.0
# 2023-10-02     795.0
# 2023-11-01     890.0
# 2023-12-01     930.0
# 2024-01-02     980.0
# 2024-02-01    1180.0
# 2024-03-01    1025.0
# 2024-04-03     990.0
# 2024-05-02    1025.0
# 2024-06-03    1220.0
# 2024-07-01    1390.0
# 2024-08-01    1365.0
# 2024-09-02    1290.0
# dtype: float64

# %%
sueldo=pd.read_csv("datos.csv")

# %%
sueldo=sueldo.iloc[:,3:5]

# %%
sueldo
# Out:
#         Fecha.1  Sueldo
# 0    31/08/2021  96000.0
# 1    29/09/2021  96000.0
# 2    29/10/2021  96000.0
# 3    30/11/2021  96000.0
# 4    30/12/2021  96000.0
# ..          ...      ...
# 916         NaN      NaN
# 917         NaN      NaN
# 918         NaN      NaN
# 919         NaN      NaN
# 920         NaN      NaN
#
# [921 rows x 2 columns]

# %%
sueldo=sueldo.set_index("Fecha.1")

# %%
sueldo
# Out:
#             Sueldo
# Fecha.1
# 31/08/2021  96000.0
# 29/09/2021  96000.0
# 29/10/2021  96000.0
# 30/11/2021  96000.0
# 30/12/2021  96000.0
# ...             ...
# NaN             NaN
# NaN             NaN
# NaN             NaN
# NaN             NaN
# NaN             NaN
#
# [921 rows x 1 columns]

# %%
sueldo=sueldo.dropna(how="any")

# %%
len(sueldo)
# Out:
# 36

# %%
sueldo
# Out:
#              Sueldo
# Fecha.1
# 31/08/2021   96000.0
# 29/09/2021   96000.0
# 29/10/2021   96000.0
# 30/11/2021   96000.0
# 30/12/2021   96000.0
# 31/01/2022   96000.0
# 25/02/2022   96000.0
# 31/03/2022   96000.0
# 29/04/2022  126720.0
# 31/05/2022  126720.0
# 30/06/2022  126720.0
# 29/07/2022  126720.0
# 31/08/2022  126720.0
# 29/09/2022  126720.0
# 31/10/2022  164736.0
# 30/11/2022  164736.0
# 29/12/2022  164736.0
# 31/01/2023  227920.0
# 28/02/2023  205920.0
# 31/03/2023  205920.0
# 28/04/2023  235810.0
# 31/05/2023  236810.0
# 30/06/2023  272330.0
# 31/07/2023  272330.0
# 31/08/2023  417793.0
# 29/09/2023  413400.0
# 31/10/2023  413400.0
# 30/11/2023  530000.0
# 29/12/2023  530000.0
# 31/01/2024  530000.0
# 29/02/2024  530000.0
# 27/03/2024  689000.0
# 30/04/2024  821500.0
# 31/05/2024  821500.0
# 28/06/2024  821500.0
# 31/07/2024  821500.0

# %%
sueldo.index =pd.to_datetime(sueldo.index, dayfirst=False)
# Out:
# /tmp/ipykernel_59528/736922632.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sueldo.index =pd.to_datetime(sueldo.index, dayfirst=False)

# %%
sueldo
# Out:
#              Sueldo
# Fecha.1
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
len(sueldo)
# Out:
# 36

# %%
sueldo=sueldo.groupby("Fecha.1").first()

# %%
len(sueldo)
# Out:
# 36

# %%
sueldo
# Out:
#              Sueldo
# Fecha.1
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
sueldo.index =pd.to_datetime(sueldo.index, dayfirst=False)

# %%
sueldo
# Out:
#              Sueldo
# Fecha.1
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
sueldo.sort_index()
# Out:
#              Sueldo
# Fecha.1
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
sueldo['Sueldo ']=sueldo['Sueldo '].astype(float)

# %%
sueldo=sueldo.sort_index()

# %%
sueldo
# Out:
#              Sueldo
# Fecha.1
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
sueldo.columns = ["Sueldo"]

# %%
sueldo
# Out:
#               Sueldo
# Fecha.1
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
sueldo["Sueldo"]
# Out:
# Fecha
# 2021-08-31     96000.0
# 2021-09-29     96000.0
# 2021-10-29     96000.0
# 2021-11-30     96000.0
# 2021-12-30     96000.0
# 2022-01-31     96000.0
# 2022-02-25     96000.0
# 2022-03-31     96000.0
# 2022-04-29    126720.0
# 2022-05-31    126720.0
# 2022-06-30    126720.0
# 2022-07-29    126720.0
# 2022-08-31    126720.0
# 2022-09-29    126720.0
# 2022-10-31    164736.0
# 2022-11-30    164736.0
# 2022-12-29    164736.0
# 2023-01-31    227920.0
# 2023-02-28    205920.0
# 2023-03-31    205920.0
# 2023-04-28    235810.0
# 2023-05-31    236810.0
# 2023-06-30    272330.0
# 2023-07-31    272330.0
# 2023-08-31    417793.0
# 2023-09-29    413400.0
# 2023-10-31    413400.0
# 2023-11-30    530000.0
# 2023-12-29    530000.0
# 2024-01-31    530000.0
# 2024-02-29    530000.0
# 2024-03-27    689000.0
# 2024-04-30    821500.0
# 2024-05-31    821500.0
# 2024-06-28    821500.0
# 2024-07-31    821500.0
# Name: Sueldo, dtype: float64

# %%
sueldo.index.name="Fecha"

# %%
sueldo
# Out:
#               Sueldo
# Fecha
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
len(sueldo)
# Out:
# 36

# %%
len(df_promedio)
# Out:
# 39

# %%
d=df_promedio.copy()

# %%
s=sueldo.copy()

# %%
s
# Out:
#               Sueldo
# Fecha
# 2021-08-31   96000.0
# 2021-09-29   96000.0
# 2021-10-29   96000.0
# 2021-11-30   96000.0
# 2021-12-30   96000.0
# 2022-01-31   96000.0
# 2022-02-25   96000.0
# 2022-03-31   96000.0
# 2022-04-29  126720.0
# 2022-05-31  126720.0
# 2022-06-30  126720.0
# 2022-07-29  126720.0
# 2022-08-31  126720.0
# 2022-09-29  126720.0
# 2022-10-31  164736.0
# 2022-11-30  164736.0
# 2022-12-29  164736.0
# 2023-01-31  227920.0
# 2023-02-28  205920.0
# 2023-03-31  205920.0
# 2023-04-28  235810.0
# 2023-05-31  236810.0
# 2023-06-30  272330.0
# 2023-07-31  272330.0
# 2023-08-31  417793.0
# 2023-09-29  413400.0
# 2023-10-31  413400.0
# 2023-11-30  530000.0
# 2023-12-29  530000.0
# 2024-01-31  530000.0
# 2024-02-29  530000.0
# 2024-03-27  689000.0
# 2024-04-30  821500.0
# 2024-05-31  821500.0
# 2024-06-28  821500.0
# 2024-07-31  821500.0

# %%
df_union = pd.concat([d, s], axis=0)

# %%
df_union.columns=['Dolar','Sueldo']

# %%
df_union
# Out:
#             Dolar    Sueldo
# Fecha
# 2021-07-01  166.5       NaN
# 2021-08-02  178.0       NaN
# 2021-09-01  178.0       NaN
# 2021-10-01  184.0       NaN
# 2021-11-01  194.5       NaN
# ...           ...       ...
# 2024-03-27    NaN  689000.0
# 2024-04-30    NaN  821500.0
# 2024-05-31    NaN  821500.0
# 2024-06-28    NaN  821500.0
# 2024-07-31    NaN  821500.0
#
# [75 rows x 2 columns]

# %%
union=df_union.groupby(df_union.index.to_period('M')).first()

# %%
union
# Out:
#           Dolar    Sueldo
# Fecha
# 2021-07   166.5       NaN
# 2021-08   178.0   96000.0
# 2021-09   178.0   96000.0
# 2021-10   184.0   96000.0
# 2021-11   194.5   96000.0
# 2021-12   198.5   96000.0
# 2022-01   204.0   96000.0
# 2022-02   212.0   96000.0
# 2022-03   204.0   96000.0
# 2022-04   198.0  126720.0
# 2022-05   199.0  126720.0
# 2022-06   204.0  126720.0
# 2022-07   237.0  126720.0
# 2022-08   277.0  126720.0
# 2022-09   282.5  126720.0
# 2022-10   282.0  164736.0
# 2022-11   288.0  164736.0
# 2022-12   311.0  164736.0
# 2023-01   344.0  227920.0
# 2023-02   379.0  205920.0
# 2023-03   373.0  205920.0
# 2023-04   393.0  235810.0
# 2023-05   466.5  236810.0
# 2023-06   487.5  272330.0
# 2023-07   492.5  272330.0
# 2023-08   557.5  417793.0
# 2023-09   730.0  413400.0
# 2023-10   795.0  413400.0
# 2023-11   890.0  530000.0
# 2023-12   930.0  530000.0
# 2024-01   980.0  530000.0
# 2024-02  1180.0  530000.0
# 2024-03  1025.0  689000.0
# 2024-04   990.0  821500.0
# ...

# %%
union=union.dropna(how="any")

# %%
union
# Out:
#           Dolar    Sueldo
# Fecha
# 2021-08   178.0   96000.0
# 2021-09   178.0   96000.0
# 2021-10   184.0   96000.0
# 2021-11   194.5   96000.0
# 2021-12   198.5   96000.0
# 2022-01   204.0   96000.0
# 2022-02   212.0   96000.0
# 2022-03   204.0   96000.0
# 2022-04   198.0  126720.0
# 2022-05   199.0  126720.0
# 2022-06   204.0  126720.0
# 2022-07   237.0  126720.0
# 2022-08   277.0  126720.0
# 2022-09   282.5  126720.0
# 2022-10   282.0  164736.0
# 2022-11   288.0  164736.0
# 2022-12   311.0  164736.0
# 2023-01   344.0  227920.0
# 2023-02   379.0  205920.0
# 2023-03   373.0  205920.0
# 2023-04   393.0  235810.0
# 2023-05   466.5  236810.0
# 2023-06   487.5  272330.0
# 2023-07   492.5  272330.0
# 2023-08   557.5  417793.0
# 2023-09   730.0  413400.0
# 2023-10   795.0  413400.0
# 2023-11   890.0  530000.0
# 2023-12   930.0  530000.0
# 2024-01   980.0  530000.0
# 2024-02  1180.0  530000.0
# 2024-03  1025.0  689000.0
# 2024-04   990.0  821500.0
# 2024-05  1025.0  821500.0
# ...

# %%
df=union.copy()

# %%
df['Sueldo_Dolar'] = df['Sueldo'] / df['Dolar']

# %%
df['extra'] = 1

# %%
df.drop(columns=['extra'], inplace=True)

# %%
# Out:
#           Dolar    Sueldo  Sueldo_Dolar
# Fecha
# 2021-08   178.0   96000.0    539.325843
# 2021-09   178.0   96000.0    539.325843
# 2021-10   184.0   96000.0    521.739130
# 2021-11   194.5   96000.0    493.573265
# 2021-12   198.5   96000.0    483.627204
# 2022-01   204.0   96000.0    470.588235
# 2022-02   212.0   96000.0    452.830189
# 2022-03   204.0   96000.0    470.588235
# 2022-04   198.0  126720.0    640.000000
# 2022-05   199.0  126720.0    636.783920
# 2022-06   204.0  126720.0    621.176471
# 2022-07   237.0  126720.0    534.683544
# 2022-08   277.0  126720.0    457.472924
# 2022-09   282.5  126720.0    448.566372
# 2022-10   282.0  164736.0    584.170213
# 2022-11   288.0  164736.0    572.000000
# 2022-12   311.0  164736.0    529.697749
# 2023-01   344.0  227920.0    662.558140
# 2023-02   379.0  205920.0    543.324538
# 2023-03   373.0  205920.0    552.064343
# 2023-04   393.0  235810.0    600.025445
# 2023-05   466.5  236810.0    507.631297
# ...
