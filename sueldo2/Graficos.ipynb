# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datos-procesados.csv')

# %%
df.head(4)
# Out:
#      Fecha  Compra  Venta   DMed  DiaD   Sueldo  DiaS   Real       Hoy
# 0  2021-08   177.0  182.0  179.5    31  96000.0    31  534.8  673848.0
# 1  2021-09   182.0  186.0  184.0    30  96000.0    29  521.7  657342.0
# 2  2021-10   193.5  197.5  195.5    29  96000.0    29  491.0  618660.0
# 3  2021-11   197.5  201.5  199.5    30  96000.0    30  481.2  606312.0

# %%
plt.plot(df['Fecha'], df['Hoy'])

# %%
df3['Pr3'] = df3['Hoy'].rolling(window=3, min_periods=1).mean().round(1)

# %%
df_filtrado = df3[(df3['Fecha'].dt.year >= 2022) ]

# %%
df2=df2.groupby(df2.index.to_period('M')).first()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# Asegurarte de que la columna 'Fecha' sea de tipo datetime
df4['Fecha'] = pd.to_datetime(df4['Fecha'])

# Crear el gráfico
plt.plot(df4['Fecha'], df4['Hoy'])

# Formatear el eje x para que muestre divisiones por año
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Divisiones por año
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Mostrar solo el año
plt.gca().xaxis.set_minor_locator(mdates.MonthLocator())
# Etiquetas y título del gráfico
plt.xlabel('Año')
plt.ylabel('Sueldo')
plt.title('Evolución del Sueldo a lo largo de los años')

# Rotar las etiquetas del eje x para mejor visibilidad
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
